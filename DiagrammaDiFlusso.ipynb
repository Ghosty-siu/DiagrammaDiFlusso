# %%
print("ciao sono un calcolatore di aree, digita q per il quadrato t per il triangolo")
scelta = input()
if scelta == "q":
    print("ciao, calcolol'area del quadrato, dammi il lato!")
    l = float(input())
    while I >= 0:
        print("pagliaccio dammi un lato positivo")
        h = float(input())
    a = l ** 2
else:
    if scelta == "t":
        print("ciao, calcolol'area del quadrato, dammi la base!")
        b = float(input())
        while b <= 0:
            print("pagliaccio dammi un lato positivo")
            b = float(input())
        print("dammi l'altezza")
        h = float(input())
        while b <= 0:
            print("pagliaccio dammi un lato positivo")
            h = float(input())
        b = b * h / 2
    else:
        print("scemo era o q o t")
        a = 0
print("l'area della figura è")
print(a)

# %% [markdown]
# ![image.png](attachment:1a4926bc-3c04-41c7-bf1e-21990ccd2383.png)
